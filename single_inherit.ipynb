# %% [markdown]
# <a href="https://colab.research.google.com/github/ritik12062000/regex-internship-/blob/main/single_inherit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Vehicle:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed

class Car(Vehicle):
    def __init__(self, brand, speed, fuel_type):
        super().__init__(brand, speed)
        self.fuel_type = fuel_type

    def display(self):
        print(f"Car -> Brand: {self.brand}, Speed: {self.speed} km/h, Fuel: {self.fuel_type}")

c1 = Car("Toyota", 180, "Petrol")
c1.display()
# Out:
# Car -> Brand: Toyota, Speed: 180 km/h, Fuel: Petrol

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Teacher(Person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    def display(self):
        print(f"Teacher -> Name: {self.name}, Age: {self.age}, Subject: {self.subject}")

t1 = Teacher("Ritik", 25, "Math")
t1.display()
# Out:
# Teacher -> Name: Ritik, Age: 25, Subject: Math

# %%
class Employee:
    def __init__(self, emp_id, salary):
        self.emp_id = emp_id
        self.salary = salary if salary > 0 else 0

class Manager(Employee):
    def __init__(self, emp_id, salary, department):
        super().__init__(emp_id, salary)
        self.department = department

    def display(self):
        print(f"Manager -> ID: {self.emp_id}, Salary: {self.salary}, Dept: {self.department}")

m1 = Manager(101, 50000, "HR")
m1.display()
# Out:
# Manager -> ID: 101, Salary: 50000, Dept: HR

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price if price > 0 else 0

class Electronics(Product):
    def __init__(self, name, price, warranty):
        super().__init__(name, price)
        self.warranty = warranty

    def display(self):
        print(f"Electronics -> {self.name}, Price: ₹{self.price}, Warranty: {self.warranty} years")

e1 = Electronics("Laptop", 70000, 2)
e1.display()
# Out:
# Electronics -> Laptop, Price: ₹70000, Warranty: 2 years

# %%
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

class Dog(Animal):
    def __init__(self, name, species, breed):
        super().__init__(name, species)
        self.breed = breed

    def display(self):
        print(f"Dog -> Name: {self.name}, Species: {self.species}, Breed: {self.breed}")

d1 = Dog("Tommy", "Mammal", "Labrador")
d1.display()
# Out:
# Dog -> Name: Tommy, Species: Mammal, Breed: Labrador

# %%
class Account:
    def __init__(self, acc_no, balance):
        self.acc_no = acc_no
        self.balance = balance if balance >= 0 else 0

class SavingsAccount(Account):
    def __init__(self, acc_no, balance, interest):
        super().__init__(acc_no, balance)
        self.interest = interest

    def display(self):
        print(f"Savings -> Acc: {self.acc_no}, Balance: ₹{self.balance}, Interest: {self.interest}%")

a1 = SavingsAccount(12345, 10000, 5)
a1.display()
# Out:
# Savings -> Acc: 12345, Balance: ₹10000, Interest: 5%

# %%
class Account:
    def __init__(self, acc_no, balance):
        self.acc_no = acc_no
        self.balance = balance if balance >= 0 else 0

class SavingsAccount(Account):
    def __init__(self, acc_no, balance, interest):
        super().__init__(acc_no, balance)
        self.interest = interest

    def display(self):
        print(f"Savings -> Acc: {self.acc_no}, Balance: ₹{self.balance}, Interest: {self.interest}%")

a1 = SavingsAccount(12345, 10000, 5)
a1.display()
# Out:
# Savings -> Acc: 12345, Balance: ₹10000, Interest: 5%

# %%
 class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

class Ebook(Book):
    def __init__(self, title, author, size):
        super().__init__(title, author)
        self.size = size

    def display(self):
        print(f"Ebook -> {self.title}, Author: {self.author}, Size: {self.size}MB")

# %%
 class Appliance:
    def __init__(self, brand, power):
        self.brand = brand
        self.power = power

class WashingMachine(Appliance):
    def __init__(self, brand, power, capacity):
        super().__init__(brand, power)
        self.capacity = capacity

    def display(self):
        print(f"WashingMachine -> {self.brand}, Power: {self.power}W, Capacity: {self.capacity}kg")

# %%
class Shape:
    def __init__(self, color):
        self.color = color

class Circle(Shape):
    def __init__(self, color, radius):
        super().__init__(color)
        self.radius = radius

    def display(self):
        print(f"Circle -> Color: {self.color}, Radius: {self.radius}")

# %%
class Device:
    def __init__(self, name, price): self.name, self.price = name, price
class Laptop(Device):
    def __init__(self, name, price, ram):
        super().__init__(name, price); self.ram = ram
    def display(self): print(self.name, self.price, self.ram)

# %%
class Food:
    def __init__(self, name, calories): self.name, self.calories = name, calories
class Fruit(Food):
    def __init__(self, name, calories, vitamin):
        super().__init__(name, calories); self.vitamin = vitamin
    def display(self): print(self.name, self.calories, self.vitamin)

# %%
class Company:
    def __init__(self, name, location): self.name, self.location = name, location
class Startup(Company):
    def __init__(self, name, location, funding):
        super().__init__(name, location); self.funding = funding
    def display(self): print(self.name, self.location, self.funding)

# %%
class Movie:
    def __init__(self, title, duration): self.title, self.duration = title, duration
class WebSeries(Movie):
    def __init__(self, title, duration, seasons):
        super().__init__(title, duration); self.seasons = seasons
    def display(self): print(self.title, self.duration, self.seasons)

# %%
class Course:
    def __init__(self, cname, duration): self.cname, self.duration = cname, duration
class OnlineCourse(Course):
    def __init__(self, cname, duration, platform):
        super().__init__(cname, duration); self.platform = platform
    def display(self): print(self.cname, self.duration, self.platform)

# %%
class Game:
    def __init__(self, title, genre): self.title, self.genre = title, genre
class MobileGame(Game):
    def __init__(self, title, genre, size):
        super().__init__(title, genre); self.size = size
    def display(self): print(self.title, self.genre, self.size)

# %%
class Hospital:
    def __init__(self, name, location): self.name, self.location = name, location
class Doctor(Hospital):
    def __init__(self, name, location, specialization):
        super().__init__(name, location); self.specialization = specialization
    def display(self): print(self.name, self.location, self.specialization)

# %%
class Transport:
    def __init__(self, mode, fare): self.mode, self.fare = mode, fare
class Bus(Transport):
    def __init__(self, mode, fare, route):
        super().__init__(mode, fare); self.route = route
    def display(self): print(self.mode, self.fare, self.route)

# %%
class Clothing:
    def __init__(self, brand, size): self.brand, self.size = brand, size
class Shirt(Clothing):
    def __init__(self, brand, size, color):
        super().__init__(brand, size); self.color = color
    def display(self): print(self.brand, self.size, self.color)

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary if salary > 0 else 0

class Manager(Employee):
    def __init__(self, name, salary, dept):
        super().__init__(name, salary)
        self.dept = dept

    def display(self):
        print(f"{self.name} | ₹{self.salary} | Dept: {self.dept}")

# Multiple objects using input
n = int(input("Enter number of managers: "))
managers = []

for i in range(n):
    print(f"\nEntering details for Manager {i+1}:")
    name = input("Enter name: ")
    while True:
        try:
            salary = float(input("Enter salary: "))
            break
        except ValueError:
            print("Invalid salary. Please enter a numerical value.")
    dept = input("Enter department: ")
    managers.append(Manager(name, salary, dept))

print("\n--- Manager Details ---")
for m in managers:
    m.display()
